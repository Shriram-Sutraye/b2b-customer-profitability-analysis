# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
os.chdir('/workspaces/b2b-customer-profitability-analysis')

# Load ONLY the raw datasets
customers = pd.read_csv('data/processed/01_customer_master.csv')
transactions = pd.read_csv('data/generated/02_transactions_generated.csv')
products = pd.read_csv('data/generated/03_products_generated.csv')

print("INITIAL EDA - RAW DATA ONLY ")
# PART 1: DATA QUALITY
print("\n1. DATA QUALITY CHECK")
print(f"Customers: {len(customers):,} rows, {customers.isnull().sum().sum()} nulls")
print(f"Transactions: {len(transactions):,} rows, {transactions.isnull().sum().sum()} nulls")
print(f"Products: {len(products):,} rows, {products.isnull().sum().sum()} nulls")

# PART 2: CUSTOMER OVERVIEW
print("\n2. CUSTOMER OVERVIEW")
print(f"By Channel: {customers['ChannelName'].value_counts().to_dict()}")
print(f"By Segment: {customers['CustomerSegment'].value_counts().to_dict()}")
print(f"By Region: {customers['RegionName'].value_counts().to_dict()}")

# PART 3: TRANSACTION PATTERNS
print("\n3. TRANSACTION PATTERNS")
print(f"Total Transactions: {len(transactions):,}")
print(f"Avg Orders per Customer: {len(transactions) / len(customers):.1f}")
print(f"Date Range: {transactions['TransactionDate'].min()} to {transactions['TransactionDate'].max()}")

# PART 4: DISTRIBUTION
print("\n4. TRANSACTION AMOUNT DISTRIBUTION")
print(f"Min: {transactions['TransactionAmount'].min():.2f}")
print(f"Max: {transactions['TransactionAmount'].max():.2f}")
print(f"Mean: {transactions['TransactionAmount'].mean():.2f}")
print(f"Median: {transactions['TransactionAmount'].median():.2f}")

# PART 5: PRODUCT MIX
print("\n5. PRODUCT CATEGORIES")
print(transactions['ProductCategory'].value_counts())

# PART 6: ORDER PATTERNS
print("\n6. ORDER PATTERNS")
print(f"Standard Orders: {(~transactions['IsUrgent']).sum():,} ({(~transactions['IsUrgent']).sum() / len(transactions) * 100:.1f}%)")
print(f"Urgent Orders: {transactions['IsUrgent'].sum():,} ({transactions['IsUrgent'].sum() / len(transactions) * 100:.1f}%)")

# PART 7: CHANNEL TRANSACTION VOLUME
transactions_with_channel = transactions.merge(
    customers[['CustomerID', 'ChannelName', 'CustomerSegment']], 
    on='CustomerID'
)

print("\n7. TRANSACTION VOLUME BY CHANNEL")
channel_trans = transactions_with_channel.groupby('ChannelName').agg({
    'TransactionAmount': ['count', 'sum', 'mean']
}).round(2)
channel_trans.columns = ['Order_Count', 'Total_Revenue', 'Avg_Order_Value']
print(channel_trans)

# PART 8: SEGMENT TRANSACTION VOLUME
print("\n8. TRANSACTION VOLUME BY SEGMENT")
segment_trans = transactions_with_channel.groupby('CustomerSegment').agg({
    'TransactionAmount': ['count', 'sum', 'mean']
}).round(2)
segment_trans.columns = ['Order_Count', 'Total_Revenue', 'Avg_Order_Value']
print(segment_trans)
# Out:
# INITIAL EDA - RAW DATA ONLY
#
# 1. DATA QUALITY CHECK
# Customers: 440 rows, 0 nulls
# Transactions: 14,488 rows, 0 nulls
# Products: 275 rows, 0 nulls
#
# 2. CUSTOMER OVERVIEW
# By Channel: {'HORECA': 298, 'Retail': 142}
# By Segment: {'Mid-Market': 228, 'SMB': 146, 'Enterprise': 66}
# By Region: {'Other_Regions': 316, 'Lisbon': 77, 'Porto': 47}
#
# 3. TRANSACTION PATTERNS
# Total Transactions: 14,488
# Avg Orders per Customer: 32.9
# Date Range: 2023-01-01 to 2023-12-28
#
# 4. TRANSACTION AMOUNT DISTRIBUTION
# Min: 16.15
# Max: 31214.25
# Mean: 1009.08
# Median: 534.89
#
# 5. PRODUCT CATEGORIES
# ProductCategory
# Fresh              6214
# Grocery            2862
# Milk               2197
# Frozen             1786
# DetergentsPaper     722
# Delicatessen        707
# Name: count, dtype: int64
#
# 6. ORDER PATTERNS
# Standard Orders: 12,876 (88.9%)
# Urgent Orders: 1,612 (11.1%)
#
# 7. TRANSACTION VOLUME BY CHANNEL
#              Order_Count  Total_Revenue  Avg_Order_Value
# ChannelName
# HORECA             12412     7999568.65           644.50
# Retail              2076     6619930.85          3188.79
#
# 8. TRANSACTION VOLUME BY SEGMENT
#                  Order_Count  Total_Revenue  Avg_Order_Value
# CustomerSegment
# Enterprise              1717     5215782.71          3037.73
# Mid-Market              6843     7446612.98          1088.21
# SMB                     5928     1957103.81           330.15

# %%
import snowflake.connector
from pathlib import Path

exec(open(Path.home() / '.snowflake_config.py').read())

conn = snowflake.connector.connect(**SNOWFLAKE_CONFIG)
cursor = conn.cursor()
cursor.execute("SHOW TABLES IN B2B_PROFITABILITY.PUBLIC")
tables = cursor.fetchall()
print("✅ Tables found:")
for table in tables:
    print(f"   {table[1]}")
conn.close()
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       2 from pathlib import Path
#       4 exec(open(Path.home() / '.snowflake_config.py').read())
# ----> 6 conn = snowflake.connector.connect(**SNOWFLAKE_CONFIG)
#       7 cursor = conn.cursor()
#       8 cursor.execute("SHOW TABLES IN B2B_PROFITABILITY.PUBLIC")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/__init__.py:54, in Connect(**kwargs)
#      52 @wraps(SnowflakeConnection.__init__)
#      53 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 54     return SnowflakeConnection(**kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/connection.py:654, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     652     kwargs = _get_default_connection_params()
#     653 self.__set_error_attributes()
# --> 654 self.connect(**kwargs)
#     655 self._telemetry = TelemetryClient(self._rest)
#     656 self.expired = False
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/connection.py:1120, in SnowflakeConnection.connect(self, **kwargs)
#    1118             raise Exception(str(exceptions_dict))
#    1119 else:
# -> 1120     self.__open_connection()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/connection.py:1536, in SnowflakeConnection.__open_connection(self)
#    1528 else:
#    1529     # okta URL, e.g., https://<account>.okta.com/
#    1530     self.auth_class = AuthByOkta(
#    1531         application=self.application,
#    1532         timeout=self.login_timeout,
#    1533         backoff_generator=self._backoff_generator,
#    1534     )
# -> 1536 self.authenticate_with_retry(self.auth_class)
#    1538 self._password = None  # ensure password won't persist
#    1539 self.auth_class.reset_secrets()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/connection.py:1870, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1867 def authenticate_with_retry(self, auth_instance) -> None:
#    1868     # make some changes if needed before real __authenticate
#    1869     try:
# -> 1870         self._authenticate(auth_instance)
#    1871     except ReauthenticationRequest as ex:
#    1872         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1873         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/connection.py:1902, in SnowflakeConnection._authenticate(self, auth_instance)
#    1900 auth_instance._retry_ctx.set_start_time()
#    1901 try:
# -> 1902     auth.authenticate(
#    1903         auth_instance=auth_instance,
#    1904         account=self.account,
#    1905         user=self.user,
#    1906         database=self.database,
#    1907         schema=self.schema,
#    1908         warehouse=self.warehouse,
#    1909         role=self.role,
#    1910         passcode=self._passcode,
#    1911         passcode_in_password=self._passcode_in_password,
#    1912         mfa_callback=self._mfa_callback,
#    1913         password_callback=self._password_callback,
#    1914         session_parameters=self._session_parameters,
#    1915     )
#    1916 except OperationalError as e:
#    1917     logger.debug(
#    1918         "Operational Error raised at authentication"
#    1919         f"for authenticator: {type(auth_instance).__name__}"
#    1920     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/auth/_auth.py:242, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     233 logger.debug(
#     234     "body['data']: %s",
#     235     {
#    (...)    238     },
#     239 )
#     241 try:
# --> 242     ret = self._rest._post_request(
#     243         url,
#     244         headers,
#     245         json.dumps(body),
#     246         socket_timeout=auth_instance._socket_timeout,
#     247     )
#     248 except ForbiddenError as err:
#     249     # HTTP 403
#     250     raise err.__class__(
#     251         msg=(
#     252             "Failed to connect to DB. "
#    (...)    259         sqlstate=SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     260     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/network.py:747, in SnowflakeRestful._post_request(self, url, headers, body, token, external_session_id, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     744     ret = probe_connection(full_url)
#     745     pprint(ret)
# --> 747 ret = self.fetch(
#     748     "post",
#     749     full_url,
#     750     headers,
#     751     data=body,
#     752     timeout=timeout,
#     753     token=token,
#     754     external_session_id=external_session_id,
#     755     no_retry=no_retry,
#     756     _include_retry_params=_include_retry_params,
#     757     socket_timeout=socket_timeout,
#     758 )
#     759 logger.debug(
#     760     "ret[code] = {code}, after post request".format(
#     761         code=(ret.get("code", "N/A"))
#     762     )
#     763 )
#     765 if ret.get("code") == MASTER_TOKEN_EXPIRED_GS_CODE:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/network.py:866, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     864 retry_ctx.set_start_time()
#     865 while True:
# --> 866     ret = self._request_exec_wrapper(
#     867         session, method, full_url, headers, data, retry_ctx, **kwargs
#     868     )
#     869     if ret is not None:
#     870         return ret
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/network.py:1007, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, external_session_id, **kwargs)
#    1003 except Exception as e:
#    1004     if (
#    1005         raise_raw_http_failure and isinstance(e, requests.exceptions.HTTPError)
#    1006     ) or not no_retry:
# -> 1007         raise e
#    1008     logger.debug("Ignored error", exc_info=True)
#    1009     return {}
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/network.py:917, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, external_session_id, **kwargs)
#     915 raise_raw_http_failure = kwargs.pop("raise_raw_http_failure", False)
#     916 try:
# --> 917     return_object = self._request_exec(
#     918         session=session,
#     919         method=method,
#     920         full_url=full_url,
#     921         headers=headers,
#     922         data=data,
#     923         token=token,
#     924         external_session_id=external_session_id,
#     925         raise_raw_http_failure=raise_raw_http_failure,
#     926         **kwargs,
#     927     )
#     928     if return_object is not None:
#     929         return return_object
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/network.py:1214, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, external_session_id, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1212         raise RetryRequest(err)
#    1213 except Exception as err:
# -> 1214     raise err
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/network.py:1161, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, external_session_id, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1159         if raise_raw_http_failure:
#    1160             raw_ret.raise_for_status()
# -> 1161         raise_failed_request_error(
#    1162             self._connection, full_url, method, raw_ret
#    1163         )
#    1164         return None  # required for tests
#    1165 finally:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/network.py:227, in raise_failed_request_error(connection, url, method, response)
#     221 def raise_failed_request_error(
#     222     connection: SnowflakeConnection | None,
#     223     url: str,
#     224     method: str,
#     225     response: Response,
#     226 ) -> None:
# --> 227     Error.errorhandler_wrapper(
#     228         connection,
#     229         None,
#     230         HttpError,
#     231         {
#     232             "msg": f"{response.status_code} {response.reason}: {method} {urlsplit(url).netloc}{urlsplit(url).path}",
#     233             "errno": ER_HTTP_GENERAL_ERROR + response.status_code,
#     234             "sqlstate": SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     235         },
#     236     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/errors.py:286, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     263 @staticmethod
#     264 def errorhandler_wrapper(
#     265     connection: SnowflakeConnection | None,
#    (...)    268     error_value: dict[str, Any],
#     269 ) -> None:
#     270     """Error handler wrapper that calls the errorhandler method.
#     271
#     272     Args:
#    (...)    283         exception to the first handler in that order.
#     284     """
# --> 286     handed_over = Error.hand_to_other_handler(
#     287         connection,
#     288         cursor,
#     289         error_class,
#     290         error_value,
#     291     )
#     292     if not handed_over:
#     293         raise Error.errorhandler_make_exception(
#     294             error_class,
#     295             error_value,
#     296         )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/errors.py:344, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     342     return True
#     343 elif connection is not None:
# --> 344     connection.errorhandler(connection, cursor, error_class, error_value)
#     345     return True
#     346 return False
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/snowflake/connector/errors.py:217, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     215 errno = error_value.get("errno")
#     216 done_format_msg = error_value.get("done_format_msg")
# --> 217 raise error_class(
#     218     msg=error_value.get("msg"),
#     219     errno=None if errno is None else int(errno),
#     220     sqlstate=error_value.get("sqlstate"),
#     221     sfqid=error_value.get("sfqid"),
#     222     query=error_value.get("query"),
#     223     done_format_msg=(
#     224         None if done_format_msg is None else bool(done_format_msg)
#     225     ),
#     226     connection=connection,
#     227     cursor=cursor,
#     228 )
#
# HttpError: 290404 (08001): 404 Not Found: post ih97160.us-east-1.snowflakecomputing.com:443/session/v1/login-request
